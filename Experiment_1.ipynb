# %%
print("Welcome to EDA lab")
# Out:
# Welcome to EDA lab

# %% [markdown]
# # Exploratory Data Analysis
# ## A-2 Batch
# ### First Lab

# %%
a = 10
b = 0
print(a+b)
# Out:
# 10

# %% [markdown]
# #Basic-Programs-experiment-1

# %%
# First Python code
print("Hello World")
# Out:
# Hello World

# %%
#Many-Statments
print("Hello World")
print("Have a good day")
print("Learning python is fun ")

# Many Prints in one-line
print("Hello World","Have a good day","Learning python is fun"); print("How are u feeling today") ; print("Have a nice day")
# Out:
# Hello World
# Have a good day
# Learning python is fun
# Hello World Have a good day Learning python is fun
# How are u feeling today
# Have a nice day

# %%
i = 5
j= 7
print(i+j)
print(i-j)
print(i*j)
print(i/j)
print(i%j)
#Simple addition, subtraction , division , multiplication
# Out:
# 12
# -2
# 35
# 0.7142857142857143
# 5

# %% [markdown]
# # variables
# x= 5
# y ="hello World"
#
# print(x)
# print(y)

# %%
a = 4
A = "sally"
print(a)
print(A)
# Out:
# 4
# sally

# %%
x,y,z = "Orange","Banana","Cherry"
print(x)
print(y)
print(z)
print("")

print("Orange\nBanana\nCherry")
# Out:
# Orange
# Banana
# Cherry
#
# Orange
# Banana
# Cherry

# %%
#Understanding data-types
x = 10
y=3.14
z= "Pythion"
A = True
c = 3+2j
D = ["hello",4,5.6]
print(type(x))
print(type(y))
print(type(z))
print(type(A))
print(type(c))
print(type(D[2]))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>
# <class 'float'>

# %%
#Simple input
name = input("Enter your name")
age = int(input("Enter your age"))
print("Hello",name,"your age is",age)
print(name)
# Out:
# Enter your namepo
# Enter your age23
# Hello po your age is 23
# po

# %%
#Complex input
marks = list(map(int,input("Enter your marks in Chemistry, Maths and Physics").split()))
print(marks)
print("your average marks are :"+ str(sum(marks)/3))
# Out:
# Enter your marks in Chemistry, Maths and Physics12 34 56
# [12, 34, 56]
# your average marks are :34.0

# %%
# Area of the Circle
r = float(input("Enter the radius of the circle"))
area = 3.14*r*r
print("Area of the circle is",area)
# Out:
# Enter the radius of the circle23
# Area of the circle is 1661.06

# %%
#Simple calculator
a = int(input("Enter the first number"))
b = int(input("Enter the second number"))
operation = input("Enter the operation")
if operation == "+":
  print(a+b)
if operation =="-":
  print(a-b)
if operation =="x":
  print(a*b)
if operation == "/":
  print(a/b)
if operation == "":
  print("no output")
  print("decide what u wanna do and then try again!")
# Out:
# Enter the first number12
# Enter the second number32
# Enter the operation
# no output
# decide what u wanna do and then try again!
